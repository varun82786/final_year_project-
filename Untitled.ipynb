# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path="vitals_random.csv"

# %%
data=pd.read_csv(path)

# %%
data
# Out:
#        RelativeTimeMilliseconds  Clock    HR  Pulse  SpO2  awRR  NBP (Sys)  \
# 0                             0  14:46   NaN    NaN   NaN   0.0      156.0
# 1                             0  12:54   NaN   94.0  98.0   0.0        NaN
# 2                             0  10:30  81.0    NaN   NaN   0.0        NaN
# 3                          1000  14:46   NaN    NaN   NaN   0.0      156.0
# 4                          1000  12:54   NaN   94.0  98.0   0.0        NaN
# ...                         ...    ...   ...    ...   ...   ...        ...
# 22514                  11482000  16:05   NaN    NaN   NaN  14.0        NaN
# 22515                  11483000  16:05   NaN    NaN   NaN  14.0        NaN
# 22516                  11484000  16:05   NaN    NaN   NaN  14.0        NaN
# 22517                  11485000  16:05   NaN    NaN   NaN  14.0        NaN
# 22518                  11486000  16:05   NaN    NaN   NaN   0.0        NaN
#
#        NBP (Dia)  NBP (Mean)  NBP (Pulse)  Temp  RR  Set RR  \
# ...

# %%
data.describe()
# Out:
#        RelativeTimeMilliseconds            HR        Pulse          SpO2  \
# count              2.251900e+04  21689.000000  22404.00000  22404.000000
# mean               4.423014e+06     76.052607     76.15707     99.574897
# std                3.067723e+06     11.307946     12.22370      1.025657
# min                0.000000e+00     51.000000     51.00000     75.000000
# 25%                1.876000e+06     69.000000     69.00000     99.000000
# 50%                3.767000e+06     76.000000     76.00000    100.000000
# 75%                6.582000e+06     81.000000     81.00000    100.000000
# max                1.148600e+07    118.000000    150.00000    100.000000
#
#                awRR     NBP (Sys)     NBP (Dia)    NBP (Mean)   NBP (Pulse)  \
# count  21302.000000  22024.000000  20087.000000  20327.000000  22264.000000
# mean      10.805417     96.737014     47.491661     59.177203     76.733830
# std        3.204209     16.017108     19.453660     17.808049     12.651636
# ...

# %%
plt.scatter(data["HR"],data["Pulse"])

# %%
plt.scatter(data["HR"],data["Temp"])

# %%
plt.hist(data["SpO2"])
# Out:
# (array([1.6000e+01, 1.0000e+00, 0.0000e+00, 1.0000e+00, 2.0000e+00,
#         0.0000e+00, 2.8000e+01, 1.8000e+01, 4.2500e+02, 2.1913e+04]),
#  array([ 75. ,  77.5,  80. ,  82.5,  85. ,  87.5,  90. ,  92.5,  95. ,
#          97.5, 100. ]),
#  <BarContainer object of 10 artists>)
